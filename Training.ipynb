# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("Datasets/HousePriceIndia/ProcessedPrice.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13859 entries, 0 to 13858
# Data columns (total 21 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   number of bedrooms                     13859 non-null  int64
#  1   number of bathrooms                    13859 non-null  float64
#  2   living area                            13859 non-null  int64
#  3   lot area                               13859 non-null  int64
#  4   number of floors                       13859 non-null  float64
#  5   waterfront present                     13859 non-null  int64
#  6   condition of the house                 13859 non-null  int64
#  7   grade of the house                     13859 non-null  int64
#  8   Area of the house(excluding basement)  13859 non-null  int64
#  9   Area of the basement                   13859 non-null  int64
#  10  Built Year                             13859 non-null  int64
#  11  Renovation Year                        13859 non-null  int64
#  12  Lattitude                              13859 non-null  float64
#  13  Longitude                              13859 non-null  float64
#  14  living_area_renov                      13859 non-null  int64
#  15  lot_area_renov                         13859 non-null  int64
#  16  Number of schools nearby               13859 non-null  int64
#  17  Distance from the airport              13859 non-null  int64
#  18  Price                                  13859 non-null  int64
#  19  Age                                    13859 non-null  int64
#  20  Year since renovation                  13859 non-null  int64
# dtypes: float64(4), int64(17)
# memory usage: 2.2 MB

# %%
data.drop("waterfront present" , axis = 1 , inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13859 entries, 0 to 13858
# Data columns (total 20 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   number of bedrooms                     13859 non-null  int64
#  1   number of bathrooms                    13859 non-null  float64
#  2   living area                            13859 non-null  int64
#  3   lot area                               13859 non-null  int64
#  4   number of floors                       13859 non-null  float64
#  5   condition of the house                 13859 non-null  int64
#  6   grade of the house                     13859 non-null  int64
#  7   Area of the house(excluding basement)  13859 non-null  int64
#  8   Area of the basement                   13859 non-null  int64
#  9   Built Year                             13859 non-null  int64
#  10  Renovation Year                        13859 non-null  int64
#  11  Lattitude                              13859 non-null  float64
#  12  Longitude                              13859 non-null  float64
#  13  living_area_renov                      13859 non-null  int64
#  14  lot_area_renov                         13859 non-null  int64
#  15  Number of schools nearby               13859 non-null  int64
#  16  Distance from the airport              13859 non-null  int64
#  17  Price                                  13859 non-null  int64
#  18  Age                                    13859 non-null  int64
#  19  Year since renovation                  13859 non-null  int64
# dtypes: float64(4), int64(16)
# memory usage: 2.1 MB

# %%
correlation_col = data[['living area','Area of the house(excluding basement)','living_area_renov']]

# %%
corr_matrix = correlation_col.corr()

# %%
print(corr_matrix)
# Out:
#                                        living area  \
# living area                               1.000000
# Area of the house(excluding basement)     0.853529
# living_area_renov                         0.743280
#
#                                        Area of the house(excluding basement)  \
# living area                                                         0.853529
# Area of the house(excluding basement)                               1.000000
# living_area_renov                                                   0.725427
#
#                                        living_area_renov
# living area                                     0.743280
# Area of the house(excluding basement)           0.725427
# living_area_renov                               1.000000

# %%
corr_matrix
# Out:
#                                        living area  \
# living area                               1.000000
# Area of the house(excluding basement)     0.853529
# living_area_renov                         0.743280
#
#                                        Area of the house(excluding basement)  \
# living area                                                         0.853529
# Area of the house(excluding basement)                               1.000000
# living_area_renov                                                   0.725427
#
#                                        living_area_renov
# living area                                     0.743280
# Area of the house(excluding basement)           0.725427
# living_area_renov                               1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',fmt='.2f',linewidths=1)
plt.title('Correlation Matrix between Living Area, Area of the House (Excluding Basement), and Lot Area')
plt.show()

# %%
data.drop("Area of the house(excluding basement)" , axis = 1 , inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13859 entries, 0 to 13858
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   number of bedrooms         13859 non-null  int64
#  1   number of bathrooms        13859 non-null  float64
#  2   living area                13859 non-null  int64
#  3   lot area                   13859 non-null  int64
#  4   number of floors           13859 non-null  float64
#  5   condition of the house     13859 non-null  int64
#  6   grade of the house         13859 non-null  int64
#  7   Area of the basement       13859 non-null  int64
#  8   Built Year                 13859 non-null  int64
#  9   Renovation Year            13859 non-null  int64
#  10  Lattitude                  13859 non-null  float64
#  11  Longitude                  13859 non-null  float64
#  12  living_area_renov          13859 non-null  int64
#  13  lot_area_renov             13859 non-null  int64
#  14  Number of schools nearby   13859 non-null  int64
#  15  Distance from the airport  13859 non-null  int64
#  16  Price                      13859 non-null  int64
#  17  Age                        13859 non-null  int64
#  18  Year since renovation      13859 non-null  int64
# dtypes: float64(4), int64(15)
# memory usage: 2.0 MB

# %%
correlation_col = data[['lot area','grade of the house','Year since renovation','number of bedrooms','condition of the house','Price','Number of schools nearby']]
corr_matrix = correlation_col.corr()
corr_matrix
# Out:
#                           lot area  grade of the house  Year since renovation  \
# lot area                  1.000000            0.097238               0.015589
# grade of the house        0.097238            1.000000              -0.041984
# Year since renovation     0.015589           -0.041984               1.000000
# number of bedrooms        0.024942            0.318161              -0.016606
# condition of the house   -0.004667           -0.177237              -0.021724
# Price                     0.096008            0.647629               0.053971
# Number of schools nearby -0.010289           -0.000772              -0.009069
#
#                           number of bedrooms  condition of the house  \
# lot area                            0.024942               -0.004667
# grade of the house                  0.318161               -0.177237
# Year since renovation              -0.016606               -0.021724
# number of bedrooms                  1.000000                0.023747
# condition of the house              0.023747                1.000000
# Price                               0.298872                0.044879
# Number of schools nearby           -0.000453               -0.009987
#
#                              Price  Number of schools nearby
# lot area                  0.096008                 -0.010289
# grade of the house        0.647629                 -0.000772
# Year since renovation     0.053971                 -0.009069
# number of bedrooms        0.298872                 -0.000453
# condition of the house    0.044879                 -0.009987
# Price                     1.000000                  0.004843
# Number of schools nearby  0.004843                  1.000000

# %%
sns.boxplot(data['lot area'])
plt.show()

# %%
q1 = data['Price'].quantile(0.25)
q3 = data['Price'].quantile(0.75)
IQR = q3-q1
lower_bound = q1 -1.5*IQR
upper_bound = q3 + 1.5*IQR
outliers = data[(data['Price'] <lower_bound ) | (data['Price'] > upper_bound)]
outliers
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 73                      4                 2.50         4340    141570
# 74                      5                 2.75         3190     16920
# 154                     3                 2.50         2200      1970
# 232                     4                 1.50         2310     13300
# 233                     4                 3.50         3900      8391
# ...                   ...                  ...          ...       ...
# 13589                   4                 3.00         3180      4649
# 13590                   4                 4.50         4920    270236
# 13717                   5                 2.75         3300      7560
# 13718                   4                 2.50         3170     47502
# 13778                   3                 2.75         2700     22343
#
#        number of floors  condition of the house  grade of the house  \
# 73                  2.5                       3                  11
# 74                  1.0                       3                   9
# 154                 2.0                       3                   9
# 232                 1.0                       3                   7
# 233                 2.0                       3                  10
# ...                 ...                     ...                 ...
# 13589               2.0                       4                   9
# 13590               2.0                       3                  10
# 13717               2.0                       3                  10
# 13718               2.0                       3                  10
# 13778               1.5                       4                  10
#
#        Area of the basement  Built Year  Renovation Year  Lattitude  \
# 73                        0        1992                0    52.9105
# 74                     1500        1976                0    52.7941
# 154                     590        2008                0    52.8726
# 232                     420        1950                0    52.8532
# 233                       0        2006                0    52.9279
# ...                     ...         ...              ...        ...
# 13589                  1110        1925                0    52.8883
# 13590                  1100        2006                0    52.6995
# 13717                     0        2007                0    52.8767
# 13718                     0        1988                0    52.8795
# 13778                     0        1977                0    52.8006
#
#        Longitude  living_area_renov  lot_area_renov  Number of schools nearby  \
# 73      -114.238               2720           97138                         1
# 74      -114.350               3100           13100                         1
# 154     -114.517               1890            3505                         3
# 232     -114.400               2840           12744                         2
# 233     -114.395               3820           12268                         2
# ...          ...                ...             ...                       ...
# 13589   -114.463               2720            5980                         3
# 13590   -113.965               4920          260924                         2
# 13717   -114.308               3150            8580                         3
# 13718   -114.375               3190           35110                         2
# 13778   -114.399               3390           15682                         1
#
#        Distance from the airport    Price  Age  Year since renovation
# 73                            73  1090000   32                      0
# 74                            53  1030000   48                      0
# 154                           65  1050000   16                      0
# 232                           61  1110000   74                      0
# 233                           73  1040000   18                      0
# ...                          ...      ...  ...                    ...
# 13589                         77  1130000   99                      0
# 13590                         53  1040000   18                      0
# 13717                         59  1110000   17                      0
# 13718                         80  1040000   36                      0
# 13778                         57  1060000   47                      0
#
# [186 rows x 19 columns]

# %%
from scipy.stats import skew

# %%
skewness = skew(data['Price'])
print(skewness)
# Out:
# 0.7533625367312812

# %%
import numpy as np

# %%
data['Price']= np.log1p(data['Price'])

# %%
skewness = skew(data['Price'])
print(skewness)
# Out:
# -0.2602774979281094

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Price'], kde=True, color='skyblue', bins=30)
plt.title('Price Distribution (Transformed)', fontsize=16)
plt.xlabel('Price', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
skewness = skew(data['lot area'])
print(skewness)
# Out:
# 10.437316708504769

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['lot area'], kde=True, color='skyblue', bins=30)

plt.xlabel('lot area', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
data['lot area'] = np.log1p(data['lot area'])

# %%
skewness = skew(data['lot area'])
print(skewness)
# Out:
# 0.9583271578577003

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['lot area'], kde=True, color='skyblue', bins=30)

plt.xlabel('lot area', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
data['lot area'] = np.log1p(data['lot area'])

# %%
skewness = skew(data['lot area'])
print(skewness)
# Out:
# 0.4091110420806651

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['lot area'], kde=True, color='skyblue', bins=30)

plt.xlabel('lot area', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13859 entries, 0 to 13858
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   number of bedrooms         13859 non-null  int64
#  1   number of bathrooms        13859 non-null  float64
#  2   living area                13859 non-null  int64
#  3   lot area                   13859 non-null  float64
#  4   number of floors           13859 non-null  float64
#  5   condition of the house     13859 non-null  int64
#  6   grade of the house         13859 non-null  int64
#  7   Area of the basement       13859 non-null  int64
#  8   Built Year                 13859 non-null  int64
#  9   Renovation Year            13859 non-null  int64
#  10  Lattitude                  13859 non-null  float64
#  11  Longitude                  13859 non-null  float64
#  12  living_area_renov          13859 non-null  int64
#  13  lot_area_renov             13859 non-null  int64
#  14  Number of schools nearby   13859 non-null  int64
#  15  Distance from the airport  13859 non-null  int64
#  16  Price                      13859 non-null  float64
#  17  Age                        13859 non-null  int64
#  18  Year since renovation      13859 non-null  int64
# dtypes: float64(6), int64(13)
# memory usage: 2.0 MB

# %%
skewness = skew(data['Renovation Year'])
print(skewness)
# Out:
# 4.663811686539595

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Renovation Year'], kde=True, color='skyblue', bins=30)

plt.xlabel('lot area', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
data['Renovation Year'] = np.log1p(data['Renovation Year'])

# %%
skewness = skew(data['Renovation Year'])
print(skewness)
# Out:
# nan

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Renovation Year'], kde=True, color='skyblue', bins=30)

plt.xlabel('lot area', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
skewness = skew(data['Renovation Year'])
print(skewness)
# Out:
# nan
