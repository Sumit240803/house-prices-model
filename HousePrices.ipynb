# %%
import pandas as pd

# %%
data = pd.read_csv("Datasets/HousePriceIndia/HousePriceIndia.csv")

# %%
print(data.head())
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810635  42491                   4                 2.50         2920
# 1  6762810998  42491                   5                 2.75         2910
# 2  6762812605  42491                   4                 2.50         3310
# 3  6762812919  42491                   3                 2.00         2710
# 4  6762813105  42491                   3                 2.50         2600
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      4000               1.5                   0                0
# 1      9480               1.5                   0                0
# 2     42998               2.0                   0                0
# 3      4500               1.5                   0                0
# 4      4750               1.0                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14619 entries, 0 to 14618
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14619 non-null  int64
#  1   Date                                   14619 non-null  int64
#  2   number of bedrooms                     14619 non-null  int64
#  3   number of bathrooms                    14619 non-null  float64
#  4   living area                            14619 non-null  int64
#  5   lot area                               14619 non-null  int64
#  6   number of floors                       14619 non-null  float64
#  7   waterfront present                     14619 non-null  int64
#  8   number of views                        14619 non-null  int64
#  9   condition of the house                 14619 non-null  int64
# ...

# %%
data.drop("number of views" , axis=1 , inplace = True)

# %%
print(data.head())
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810635  42491                   4                 2.50         2920
# 1  6762810998  42491                   5                 2.75         2910
# 2  6762812605  42491                   4                 2.50         3310
# 3  6762812919  42491                   3                 2.00         2710
# 4  6762813105  42491                   3                 2.50         2600
#
#    lot area  number of floors  waterfront present  condition of the house  \
# 0      4000               1.5                   0                       5
# 1      9480               1.5                   0                       3
# 2     42998               2.0                   0                       3
# 3      4500               1.5                   0                       4
# 4      4750               1.0                   0                       4
#
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14619 entries, 0 to 14618
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14619 non-null  int64
#  1   Date                                   14619 non-null  int64
#  2   number of bedrooms                     14619 non-null  int64
#  3   number of bathrooms                    14619 non-null  float64
#  4   living area                            14619 non-null  int64
#  5   lot area                               14619 non-null  int64
#  6   number of floors                       14619 non-null  float64
#  7   waterfront present                     14619 non-null  int64
#  8   condition of the house                 14619 non-null  int64
#  9   grade of the house                     14619 non-null  int64
# ...

# %%
data.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810635  42491                   4                 2.50         2920
# 1  6762810998  42491                   5                 2.75         2910
# 2  6762812605  42491                   4                 2.50         3310
# 3  6762812919  42491                   3                 2.00         2710
# 4  6762813105  42491                   3                 2.50         2600
#
#    lot area  number of floors  waterfront present  condition of the house  \
# 0      4000               1.5                   0                       5
# 1      9480               1.5                   0                       3
# 2     42998               2.0                   0                       3
# 3      4500               1.5                   0                       4
# 4      4750               1.0                   0                       4
#
# ...

# %%
data.drop("Date" , axis=1 , inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14619 entries, 0 to 14618
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   number of bedrooms                     14619 non-null  int64
#  1   number of bathrooms                    14619 non-null  float64
#  2   living area                            14619 non-null  int64
#  3   lot area                               14619 non-null  int64
#  4   number of floors                       14619 non-null  float64
#  5   waterfront present                     14619 non-null  int64
#  6   condition of the house                 14619 non-null  int64
#  7   grade of the house                     14619 non-null  int64
#  8   Area of the house(excluding basement)  14619 non-null  int64
#  9   Area of the basement                   14619 non-null  int64
# ...

# %%
currentYear = 2024
data['Age'] = currentYear - data['Built Year']
data['Year since renovation']= currentYear - data['Renovation Year']
data['Year since renovation'] = data['Year since renovation'].where(data['Renovation Year'] !=0,0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14619 entries, 0 to 14618
# Data columns (total 21 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   number of bedrooms                     14619 non-null  int64
#  1   number of bathrooms                    14619 non-null  float64
#  2   living area                            14619 non-null  int64
#  3   lot area                               14619 non-null  int64
#  4   number of floors                       14619 non-null  float64
#  5   waterfront present                     14619 non-null  int64
#  6   condition of the house                 14619 non-null  int64
#  7   grade of the house                     14619 non-null  int64
#  8   Area of the house(excluding basement)  14619 non-null  int64
#  9   Area of the basement                   14619 non-null  int64
# ...

# %%
print(data.head())
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   4                 2.50         2920      4000
# 1                   5                 2.75         2910      9480
# 2                   4                 2.50         3310     42998
# 3                   3                 2.00         2710      4500
# 4                   3                 2.50         2600      4750
#
#    number of floors  waterfront present  condition of the house  \
# 0               1.5                   0                       5
# 1               1.5                   0                       3
# 2               2.0                   0                       3
# 3               1.5                   0                       4
# 4               1.0                   0                       4
#
#    grade of the house  Area of the house(excluding basement)  \
# 0                   8                                   1910
# ...

# %%
data['Built Year']
# Out:
# 0        1909
# 1        1939
# 2        2001
# 3        1929
# 4        1951
#          ...
# 14614    1957
# 14615    1968
# 14616    1962
# 14617    1955
# 14618    1969
# Name: Built Year, Length: 14619, dtype: int64

# %%
data['Year since renovation']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 14614     0
# 14615     0
# 14616     0
# 14617     0
# 14618    15
# Name: Year since renovation, Length: 14619, dtype: int64

# %%
data['waterfront present'] = data['waterfront present'].apply(lambda x: 1 if x else 0)

# %%
data.head()
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   4                 2.50         2920      4000
# 1                   5                 2.75         2910      9480
# 2                   4                 2.50         3310     42998
# 3                   3                 2.00         2710      4500
# 4                   3                 2.50         2600      4750
#
#    number of floors  waterfront present  condition of the house  \
# 0               1.5                   0                       5
# 1               1.5                   0                       3
# 2               2.0                   0                       3
# 3               1.5                   0                       4
# 4               1.0                   0                       4
#
#    grade of the house  Area of the house(excluding basement)  \
# 0                   8                                   1910
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14619 entries, 0 to 14618
# Data columns (total 21 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   number of bedrooms                     14619 non-null  int64
#  1   number of bathrooms                    14619 non-null  float64
#  2   living area                            14619 non-null  int64
#  3   lot area                               14619 non-null  int64
#  4   number of floors                       14619 non-null  float64
#  5   waterfront present                     14619 non-null  int64
#  6   condition of the house                 14619 non-null  int64
#  7   grade of the house                     14619 non-null  int64
#  8   Area of the house(excluding basement)  14619 non-null  int64
#  9   Area of the basement                   14619 non-null  int64
# ...

# %%
data.to_csv('Cleaned Columns.csv' , index=False)
