# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("Datasets/HousePriceIndia/ProcessedPrice.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13859 entries, 0 to 13858
# Data columns (total 21 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   number of bedrooms                     13859 non-null  int64
#  1   number of bathrooms                    13859 non-null  float64
#  2   living area                            13859 non-null  int64
#  3   lot area                               13859 non-null  int64
#  4   number of floors                       13859 non-null  float64
#  5   waterfront present                     13859 non-null  int64
#  6   condition of the house                 13859 non-null  int64
#  7   grade of the house                     13859 non-null  int64
#  8   Area of the house(excluding basement)  13859 non-null  int64
#  9   Area of the basement                   13859 non-null  int64
#  10  Built Year                             13859 non-null  int64
#  11  Renovation Year                        13859 non-null  int64
#  12  Lattitude                              13859 non-null  float64
#  13  Longitude                              13859 non-null  float64
#  14  living_area_renov                      13859 non-null  int64
#  15  lot_area_renov                         13859 non-null  int64
#  16  Number of schools nearby               13859 non-null  int64
#  17  Distance from the airport              13859 non-null  int64
#  18  Price                                  13859 non-null  int64
#  19  Age                                    13859 non-null  int64
#  20  Year since renovation                  13859 non-null  int64
# dtypes: float64(4), int64(17)
# memory usage: 2.2 MB

# %%
correlation = data.corr()

# %%
price_corr = correlation['Price'].sort_values(ascending = False)
print(price_corr)
# Out:
# Price                                    1.000000
# grade of the house                       0.647629
# living area                              0.638922
# living_area_renov                        0.577698
# Area of the house(excluding basement)    0.546075
# number of bathrooms                      0.466374
# Lattitude                                0.422816
# number of bedrooms                       0.298872
# number of floors                         0.279132
# Area of the basement                     0.237322
# lot area                                 0.096008
# Renovation Year                          0.091372
# lot_area_renov                           0.080134
# Longitude                                0.080069
# Built Year                               0.066145
# Year since renovation                    0.053971
# waterfront present                       0.053646
# condition of the house                   0.044879
# Distance from the airport                0.007484
# Number of schools nearby                 0.004843
# Age                                     -0.066145
# Name: Price, dtype: float64

# %%
X = data.drop(columns=["Price"])
correlation_matrix = X.corr()


high_corr_features = [(col1, col2) for col1 in correlation_matrix.columns 
                      for col2 in correlation_matrix.columns 
                      if col1 != col2 and abs(correlation_matrix.loc[col1, col2]) > 0.99]

print("Highly Correlated Features:", high_corr_features)


for col1, col2 in high_corr_features:
    X = X.drop(columns=[col2])
# Out:
# Highly Correlated Features: [('Built Year', 'Age'), ('Age', 'Built Year')]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13859 entries, 0 to 13858
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   number of bedrooms                     13859 non-null  int64
#  1   number of bathrooms                    13859 non-null  float64
#  2   living area                            13859 non-null  int64
#  3   lot area                               13859 non-null  int64
#  4   number of floors                       13859 non-null  float64
#  5   waterfront present                     13859 non-null  int64
#  6   condition of the house                 13859 non-null  int64
#  7   grade of the house                     13859 non-null  int64
#  8   Area of the house(excluding basement)  13859 non-null  int64
#  9   Area of the basement                   13859 non-null  int64
#  10  Renovation Year                        13859 non-null  int64
#  11  Lattitude                              13859 non-null  float64
#  12  Longitude                              13859 non-null  float64
#  13  living_area_renov                      13859 non-null  int64
#  14  lot_area_renov                         13859 non-null  int64
#  15  Number of schools nearby               13859 non-null  int64
#  16  Distance from the airport              13859 non-null  int64
#  17  Year since renovation                  13859 non-null  int64
# dtypes: float64(4), int64(14)
# memory usage: 1.9 MB

# %%
X.nunique()>1
# Out:
# number of bedrooms                       True
# number of bathrooms                      True
# living area                              True
# lot area                                 True
# number of floors                         True
# waterfront present                       True
# condition of the house                   True
# grade of the house                       True
# Area of the house(excluding basement)    True
# Area of the basement                     True
# Renovation Year                          True
# Lattitude                                True
# Longitude                                True
# living_area_renov                        True
# lot_area_renov                           True
# Number of schools nearby                 True
# Distance from the airport                True
# Year since renovation                    True
# dtype: bool

# %%
X = X.loc[:,X.nunique()>1]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13859 entries, 0 to 13858
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   number of bedrooms                     13859 non-null  int64
#  1   number of bathrooms                    13859 non-null  float64
#  2   living area                            13859 non-null  int64
#  3   lot area                               13859 non-null  int64
#  4   number of floors                       13859 non-null  float64
#  5   waterfront present                     13859 non-null  int64
#  6   condition of the house                 13859 non-null  int64
#  7   grade of the house                     13859 non-null  int64
#  8   Area of the house(excluding basement)  13859 non-null  int64
#  9   Area of the basement                   13859 non-null  int64
#  10  Renovation Year                        13859 non-null  int64
#  11  Lattitude                              13859 non-null  float64
#  12  Longitude                              13859 non-null  float64
#  13  living_area_renov                      13859 non-null  int64
#  14  lot_area_renov                         13859 non-null  int64
#  15  Number of schools nearby               13859 non-null  int64
#  16  Distance from the airport              13859 non-null  int64
#  17  Year since renovation                  13859 non-null  int64
# dtypes: float64(4), int64(14)
# memory usage: 1.9 MB

# %%
scaler = StandardScaler()

# %%
X_normalized = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
X_normalized
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 0                0.718714             0.610046     1.687492  0.746264
# 1               -0.366916            -0.094125     0.918413 -0.271116
# 2               -0.366916             0.610046     0.777415 -0.264509
# 3                1.804345             1.666302     2.136121 -0.073047
# 4               -0.366916            -0.446210     0.315967 -0.110494
# ...                   ...                  ...          ...       ...
# 13854           -1.452547            -0.798295    -0.560783  0.138500
# 13855           -0.366916            -0.094125    -0.401840 -0.205049
# 13856           -1.452547            -1.502466    -1.183737 -0.228304
# 13857            0.718714            -1.502466    -1.235009 -0.215065
# 13858           -0.366916            -1.502466    -1.401642 -0.263981
#
#        number of floors  waterfront present  condition of the house  \
# 0              0.959757           -0.057075               -0.646877
# 1              0.029728           -0.057075                0.867493
# 2             -0.900300           -0.057075                0.867493
# 3              0.959757           -0.057075               -0.646877
# 4              0.959757           -0.057075                2.381862
# ...                 ...                 ...                     ...
# 13854         -0.900300           -0.057075                0.867493
# 13855          0.029728           -0.057075                0.867493
# 13856         -0.900300           -0.057075               -0.646877
# 13857         -0.900300           -0.057075                0.867493
# 13858         -0.900300           -0.057075               -0.646877
#
#        grade of the house  Area of the house(excluding basement)  \
# 0                1.383370                               2.164078
# 1                0.423804                               0.215045
# 2                1.383370                              -0.030288
# 3                2.342936                               2.641113
# 4                0.423804                              -0.234732
# ...                   ...                                    ...
# 13854           -0.535762                              -0.226554
# 13855           -0.535762                              -0.057547
# 13856           -1.495328                              -0.888953
# 13857           -1.495328                              -0.943471
# 13858           -1.495328                              -1.120656
#
#        Area of the basement  Renovation Year  Lattitude  Longitude  \
# 0                 -0.658252        -0.205387   1.165654   0.575773
# 1                  1.355756        -0.205387   0.819290  -0.571474
# 2                  1.525612        -0.205387   0.880708  -1.305992
# 3                 -0.658252        -0.205387  -0.187665   2.471528
# 4                  1.016044        -0.205387   0.967120  -0.550488
# ...                     ...              ...        ...        ...
# 13854             -0.658252        -0.205387  -1.220330  -0.480534
# 13855             -0.658252        -0.205387  -2.017325   0.072103
# 13856             -0.658252        -0.205387  -0.436190  -0.725373
# 13857             -0.658252        -0.205387  -0.530458  -0.053814
# 13858             -0.658252         4.903162  -1.829502  -1.040166
#
#        living_area_renov  lot_area_renov  Number of schools nearby  \
# 0               2.269381        1.169110                  1.210768
# 1               0.202462       -0.308117                 -1.238336
# 2               0.715186       -0.298486                 -1.238336
# 3               2.221313       -0.048436                  1.210768
# 4              -0.582647       -0.073976                  1.210768
# ...                  ...             ...                       ...
# 13854           0.506892        0.184433                  1.210768
# 13855          -0.630715       -0.193319                  1.210768
# 13856          -1.287642       -0.245710                 -0.013784
# 13857          -0.822986       -0.226025                  1.210768
# 13858          -1.656163       -0.347410                 -0.013784
#
#        Distance from the airport  Year since renovation
# 0                       1.236614              -0.177835
# 1                      -1.563202              -0.177835
# 2                       0.228680              -0.177835
# 3                       0.788643              -0.177835
# 4                       0.676651              -0.177835
# ...                          ...                    ...
# 13854                   1.236614              -0.177835
# 13855                  -0.667261              -0.177835
# 13856                  -0.107298              -0.177835
# 13857                  -1.227224              -0.177835
# 13858                  -1.115231               2.124392
#
# [13859 rows x 18 columns]

# %%
condition_number = np.linalg.cond(X_normalized)
print("Condition Number (Normalized):", condition_number)
# Out:
# Condition Number (Normalized): 8261881475834470.0

# %%
correlation_matrix = X_normalized.corr()

# %%
high_corr_pairs = [(col1, col2) for col1 in correlation_matrix.columns
                   for col2 in correlation_matrix.columns
                   if col1 != col2 and abs(correlation_matrix.loc[col1, col2]) > 0.9]

# %%
print("Highly Correlated Feature Pairs:", high_corr_pairs)
# Out:
# Highly Correlated Feature Pairs: []

# %%
correlation_matrix
# Out:
#                                        number of bedrooms  \
# number of bedrooms                               1.000000
# number of bathrooms                              0.486262
# living area                                      0.576949
# lot area                                         0.024942
# number of floors                                 0.154136
# waterfront present                              -0.029203
# condition of the house                           0.023747
# grade of the house                               0.318161
# Area of the house(excluding basement)            0.456220
# Area of the basement                             0.279976
# Renovation Year                                 -0.001178
# Lattitude                                       -0.030734
# Longitude                                        0.143677
# living_area_renov                                0.368776
# lot_area_renov                                   0.018421
# Number of schools nearby                        -0.000453
# Distance from the airport                       -0.007217
# Year since renovation                           -0.016606
#
#                                        number of bathrooms  living area  \
# number of bedrooms                                0.486262     0.576949
# number of bathrooms                               1.000000     0.714024
# living area                                       0.714024     1.000000
# lot area                                          0.058897     0.164281
# number of floors                                  0.504215     0.341727
# waterfront present                               -0.007158     0.003280
# condition of the house                           -0.139755    -0.080572
# grade of the house                                0.612715     0.708669
# Area of the house(excluding basement)             0.634677     0.853529
# Area of the basement                              0.221754     0.373494
# Renovation Year                                   0.022499     0.022534
# Lattitude                                         0.002876     0.018633
# Longitude                                         0.247863     0.288068
# living_area_renov                                 0.530990     0.743280
# lot_area_renov                                    0.055978     0.169972
# Number of schools nearby                          0.003525     0.000083
# Distance from the airport                         0.008440     0.004495
# Year since renovation                            -0.008320     0.004976
#
#                                        lot area  number of floors  \
# number of bedrooms                     0.024942          0.154136
# number of bathrooms                    0.058897          0.504215
# living area                            0.164281          0.341727
# lot area                               1.000000         -0.011327
# number of floors                      -0.011327          1.000000
# waterfront present                     0.032710         -0.011279
# condition of the house                -0.004667         -0.286251
# grade of the house                     0.097238          0.462364
# Area of the house(excluding basement)  0.169346          0.529804
# Area of the basement                   0.009503         -0.296317
# Renovation Year                        0.009203         -0.002719
# Lattitude                             -0.097221          0.039042
# Longitude                              0.213476          0.137975
# living_area_renov                      0.144832          0.273080
# lot_area_renov                         0.701140         -0.017875
# Number of schools nearby              -0.010289         -0.008876
# Distance from the airport              0.005455          0.014523
# Year since renovation                  0.015589         -0.004096
#
#                                        waterfront present  \
# number of bedrooms                              -0.029203
# number of bathrooms                             -0.007158
# living area                                      0.003280
# lot area                                         0.032710
# number of floors                                -0.011279
# waterfront present                               1.000000
# condition of the house                           0.022622
# grade of the house                              -0.018408
# Area of the house(excluding basement)           -0.005452
# Area of the basement                             0.015916
# Renovation Year                                  0.058818
# Lattitude                                       -0.050930
# Longitude                                       -0.065871
# living_area_renov                                0.003650
# lot_area_renov                                   0.033320
# Number of schools nearby                        -0.008552
# Distance from the airport                       -0.001152
# Year since renovation                            0.066159
#
#                                        condition of the house  \
# number of bedrooms                                   0.023747
# number of bathrooms                                 -0.139755
# living area                                         -0.080572
# lot area                                            -0.004667
# number of floors                                    -0.286251
# waterfront present                                   0.022622
# condition of the house                               1.000000
# grade of the house                                  -0.177237
# Area of the house(excluding basement)               -0.191516
# Area of the basement                                 0.188434
# Renovation Year                                     -0.060172
# Lattitude                                           -0.006590
# Longitude                                           -0.114913
# living_area_renov                                   -0.124161
# lot_area_renov                                      -0.000440
# Number of schools nearby                            -0.009987
# Distance from the airport                           -0.001931
# Year since renovation                               -0.021724
#
#                                        grade of the house  \
# number of bedrooms                               0.318161
# number of bathrooms                              0.612715
# living area                                      0.708669
# lot area                                         0.097238
# number of floors                                 0.462364
# waterfront present                              -0.018408
# condition of the house                          -0.177237
# grade of the house                               1.000000
# Area of the house(excluding basement)            0.715733
# Area of the basement                             0.067310
# Renovation Year                                 -0.022548
# Lattitude                                        0.091302
# Longitude                                        0.235861
# living_area_renov                                0.679963
# lot_area_renov                                   0.103086
# Number of schools nearby                        -0.000772
# Distance from the airport                        0.006625
# Year since renovation                           -0.041984
#
#                                        Area of the house(excluding basement)  \
# number of bedrooms                                                  0.456220
# number of bathrooms                                                 0.634677
# living area                                                         0.853529
# lot area                                                            0.169346
# number of floors                                                    0.529804
# waterfront present                                                 -0.005452
# condition of the house                                             -0.191516
# grade of the house                                                  0.715733
# Area of the house(excluding basement)                               1.000000
# Area of the basement                                               -0.164551
# Renovation Year                                                    -0.000606
# Lattitude                                                          -0.038690
# Longitude                                                           0.392887
# living_area_renov                                                   0.725427
# lot_area_renov                                                      0.180829
# Number of schools nearby                                           -0.005731
# Distance from the airport                                           0.004056
# Year since renovation                                              -0.005336
#
#                                        Area of the basement  Renovation Year  \
# number of bedrooms                                 0.279976        -0.001178
# number of bathrooms                                0.221754         0.022499
# living area                                        0.373494         0.022534
# lot area                                           0.009503         0.009203
# number of floors                                  -0.296317        -0.002719
# waterfront present                                 0.015916         0.058818
# condition of the house                             0.188434        -0.060172
# grade of the house                                 0.067310        -0.022548
# Area of the house(excluding basement)             -0.164551        -0.000606
# Area of the basement                               1.000000         0.043737
# Renovation Year                                    0.043737         1.000000
# Lattitude                                          0.104154         0.022218
# Longitude                                         -0.154139        -0.072673
# living_area_renov                                  0.115573        -0.038155
# lot_area_renov                                    -0.000168         0.005640
# Number of schools nearby                           0.010361        -0.007724
# Distance from the airport                          0.001288        -0.001715
# Year since renovation                              0.018920         0.861644
#
#                                        Lattitude  Longitude  \
# number of bedrooms                     -0.030734   0.143677
# number of bathrooms                     0.002876   0.247863
# living area                             0.018633   0.288068
# lot area                               -0.097221   0.213476
# number of floors                        0.039042   0.137975
# waterfront present                     -0.050930  -0.065871
# condition of the house                 -0.006590  -0.114913
# grade of the house                      0.091302   0.235861
# Area of the house(excluding basement)  -0.038690   0.392887
# Area of the basement                    0.104154  -0.154139
# Renovation Year                         0.022218  -0.072673
# Lattitude                               1.000000  -0.129123
# Longitude                              -0.129123   1.000000
# living_area_renov                       0.019152   0.379308
# lot_area_renov                         -0.099152   0.251263
# Number of schools nearby                0.014486  -0.008472
# Distance from the airport               0.008213  -0.000453
# Year since renovation                   0.017261  -0.065374
#
#                                        living_area_renov  lot_area_renov  \
# number of bedrooms                              0.368776        0.018421
# number of bathrooms                             0.530990        0.055978
# living area                                     0.743280        0.169972
# lot area                                        0.144832        0.701140
# number of floors                                0.273080       -0.017875
# waterfront present                              0.003650        0.033320
# condition of the house                         -0.124161       -0.000440
# grade of the house                              0.679963        0.103086
# Area of the house(excluding basement)           0.725427        0.180829
# Area of the basement                            0.115573       -0.000168
# Renovation Year                                -0.038155        0.005640
# Lattitude                                       0.019152       -0.099152
# Longitude                                       0.379308        0.251263
# living_area_renov                               1.000000        0.179598
# lot_area_renov                                  0.179598        1.000000
# Number of schools nearby                       -0.006359       -0.024662
# Distance from the airport                      -0.001062       -0.011514
# Year since renovation                          -0.034239        0.009832
#
#                                        Number of schools nearby  \
# number of bedrooms                                    -0.000453
# number of bathrooms                                    0.003525
# living area                                            0.000083
# lot area                                              -0.010289
# number of floors                                      -0.008876
# waterfront present                                    -0.008552
# condition of the house                                -0.009987
# grade of the house                                    -0.000772
# Area of the house(excluding basement)                 -0.005731
# Area of the basement                                   0.010361
# Renovation Year                                       -0.007724
# Lattitude                                              0.014486
# Longitude                                             -0.008472
# living_area_renov                                     -0.006359
# lot_area_renov                                        -0.024662
# Number of schools nearby                               1.000000
# Distance from the airport                             -0.001202
# Year since renovation                                 -0.009069
#
#                                        Distance from the airport  \
# number of bedrooms                                     -0.007217
# number of bathrooms                                     0.008440
# living area                                             0.004495
# lot area                                                0.005455
# number of floors                                        0.014523
# waterfront present                                     -0.001152
# condition of the house                                 -0.001931
# grade of the house                                      0.006625
# Area of the house(excluding basement)                   0.004056
# Area of the basement                                    0.001288
# Renovation Year                                        -0.001715
# Lattitude                                               0.008213
# Longitude                                              -0.000453
# living_area_renov                                      -0.001062
# lot_area_renov                                         -0.011514
# Number of schools nearby                               -0.001202
# Distance from the airport                               1.000000
# Year since renovation                                  -0.010686
#
#                                        Year since renovation
# number of bedrooms                                 -0.016606
# number of bathrooms                                -0.008320
# living area                                         0.004976
# lot area                                            0.015589
# number of floors                                   -0.004096
# waterfront present                                  0.066159
# condition of the house                             -0.021724
# grade of the house                                 -0.041984
# Area of the house(excluding basement)              -0.005336
# Area of the basement                                0.018920
# Renovation Year                                     0.861644
# Lattitude                                           0.017261
# Longitude                                          -0.065374
# living_area_renov                                  -0.034239
# lot_area_renov                                      0.009832
# Number of schools nearby                           -0.009069
# Distance from the airport                          -0.010686
# Year since renovation                               1.000000

# %%
for col in X_normalized.columns:
    # Separate target (current column) and predictors (all other columns)
    target = X_normalized[col]
    predictors = X_normalized.drop(columns=[col])

    # Fit a linear regression model
    model = LinearRegression().fit(predictors, target)
    r_squared = model.score(predictors, target)

    if r_squared > 0.99:  # Threshold for perfect multicollinearity
        print(f"Feature {col} is highly correlated with other features (R^2 = {r_squared:.2f})")

        # Drop the feature
        X_normalized = X_normalized.drop(columns=[col])
# Out:
# Feature living area is highly correlated with other features (R^2 = 1.00)

# %%
X_normalized = X_normalized.drop(columns=["living area"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 X_normalized = X_normalized.drop(columns=["living area"])
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['living area'] not found in axis"

# %%
X_normalized
# Out:
#        number of bedrooms  number of bathrooms  lot area  number of floors  \
# 0                0.718714             0.610046  0.746264          0.959757
# 1               -0.366916            -0.094125 -0.271116          0.029728
# 2               -0.366916             0.610046 -0.264509         -0.900300
# 3                1.804345             1.666302 -0.073047          0.959757
# 4               -0.366916            -0.446210 -0.110494          0.959757
# ...                   ...                  ...       ...               ...
# 13854           -1.452547            -0.798295  0.138500         -0.900300
# 13855           -0.366916            -0.094125 -0.205049          0.029728
# 13856           -1.452547            -1.502466 -0.228304         -0.900300
# 13857            0.718714            -1.502466 -0.215065         -0.900300
# 13858           -0.366916            -1.502466 -0.263981         -0.900300
#
#        waterfront present  condition of the house  grade of the house  \
# 0               -0.057075               -0.646877            1.383370
# 1               -0.057075                0.867493            0.423804
# 2               -0.057075                0.867493            1.383370
# 3               -0.057075               -0.646877            2.342936
# 4               -0.057075                2.381862            0.423804
# ...                   ...                     ...                 ...
# 13854           -0.057075                0.867493           -0.535762
# 13855           -0.057075                0.867493           -0.535762
# 13856           -0.057075               -0.646877           -1.495328
# 13857           -0.057075                0.867493           -1.495328
# 13858           -0.057075               -0.646877           -1.495328
#
#        Area of the house(excluding basement)  Area of the basement  \
# 0                                   2.164078             -0.658252
# 1                                   0.215045              1.355756
# 2                                  -0.030288              1.525612
# 3                                   2.641113             -0.658252
# 4                                  -0.234732              1.016044
# ...                                      ...                   ...
# 13854                              -0.226554             -0.658252
# 13855                              -0.057547             -0.658252
# 13856                              -0.888953             -0.658252
# 13857                              -0.943471             -0.658252
# 13858                              -1.120656             -0.658252
#
#        Renovation Year  Lattitude  Longitude  living_area_renov  \
# 0            -0.205387   1.165654   0.575773           2.269381
# 1            -0.205387   0.819290  -0.571474           0.202462
# 2            -0.205387   0.880708  -1.305992           0.715186
# 3            -0.205387  -0.187665   2.471528           2.221313
# 4            -0.205387   0.967120  -0.550488          -0.582647
# ...                ...        ...        ...                ...
# 13854        -0.205387  -1.220330  -0.480534           0.506892
# 13855        -0.205387  -2.017325   0.072103          -0.630715
# 13856        -0.205387  -0.436190  -0.725373          -1.287642
# 13857        -0.205387  -0.530458  -0.053814          -0.822986
# 13858         4.903162  -1.829502  -1.040166          -1.656163
#
#        lot_area_renov  Number of schools nearby  Distance from the airport  \
# 0            1.169110                  1.210768                   1.236614
# 1           -0.308117                 -1.238336                  -1.563202
# 2           -0.298486                 -1.238336                   0.228680
# 3           -0.048436                  1.210768                   0.788643
# 4           -0.073976                  1.210768                   0.676651
# ...               ...                       ...                        ...
# 13854        0.184433                  1.210768                   1.236614
# 13855       -0.193319                  1.210768                  -0.667261
# 13856       -0.245710                 -0.013784                  -0.107298
# 13857       -0.226025                  1.210768                  -1.227224
# 13858       -0.347410                 -0.013784                  -1.115231
#
#        Year since renovation
# 0                  -0.177835
# 1                  -0.177835
# 2                  -0.177835
# 3                  -0.177835
# 4                  -0.177835
# ...                      ...
# 13854              -0.177835
# 13855              -0.177835
# 13856              -0.177835
# 13857              -0.177835
# 13858               2.124392
#
# [13859 rows x 17 columns]

# %%
vif = pd.DataFrame()
vif["Features"] = X_normalized.columns
vif["VIF"] = [variance_inflation_factor(X_normalized.values, i) for i in range(X_normalized.shape[1])]

# %%
print(vif)
# Out:
#                                  Features       VIF
# 0                      number of bedrooms  1.622602
# 1                     number of bathrooms  2.659250
# 2                                lot area  1.990077
# 3                        number of floors  1.992967
# 4                      waterfront present  1.017944
# 5                  condition of the house  1.132131
# 6                      grade of the house  2.729923
# 7   Area of the house(excluding basement)  4.637794
# 8                    Area of the basement  1.931817
# 9                         Renovation Year  3.959726
# 10                              Lattitude  1.067765
# 11                              Longitude  1.356644
# 12                      living_area_renov  2.820849
# 13                         lot_area_renov  2.038319
# 14               Number of schools nearby  1.001503
# 15              Distance from the airport  1.001315
# 16                  Year since renovation  3.932205

# %%
corr_matrix = data.corr()
print(corr_matrix["Area of the house(excluding basement)"].sort_values(ascending=False))
# Out:
# Area of the house(excluding basement)    1.000000
# living area                              0.853529
# living_area_renov                        0.725427
# grade of the house                       0.715733
# number of bathrooms                      0.634677
# Price                                    0.546075
# number of floors                         0.529804
# Built Year                               0.460671
# number of bedrooms                       0.456220
# Longitude                                0.392887
# lot_area_renov                           0.180829
# lot area                                 0.169346
# Distance from the airport                0.004056
# Renovation Year                         -0.000606
# Year since renovation                   -0.005336
# waterfront present                      -0.005452
# Number of schools nearby                -0.005731
# Lattitude                               -0.038690
# Area of the basement                    -0.164551
# condition of the house                  -0.191516
# Age                                     -0.460671
# Name: Area of the house(excluding basement), dtype: float64

# %%
X_normalized = X_normalized.drop(columns=["Area of the house(excluding basement)"])

# %%
vif = pd.DataFrame()
vif["Features"] = X_normalized.columns
vif["VIF"] = [variance_inflation_factor(X_normalized.values, i) for i in range(X_normalized.shape[1])]
print(vif)
# Out:
#                      Features       VIF
# 0          number of bedrooms  1.418447
# 1         number of bathrooms  2.499480
# 2                    lot area  1.980320
# 3            number of floors  1.941982
# 4          waterfront present  1.017634
# 5      condition of the house  1.131806
# 6          grade of the house  2.441570
# 7        Area of the basement  1.555350
# 8             Renovation Year  3.958185
# 9                   Lattitude  1.065246
# 10                  Longitude  1.346282
# 11          living_area_renov  2.231015
# 12             lot_area_renov  2.033609
# 13   Number of schools nearby  1.001475
# 14  Distance from the airport  1.001294
# 15      Year since renovation  3.931211

# %%
X_normalized = X_normalized.drop(columns=["Renovation Year"])

# %%
vif = pd.DataFrame()
vif["Features"] = X_normalized.columns
vif["VIF"] = [variance_inflation_factor(X_normalized.values, i) for i in range(X_normalized.shape[1])]
print(vif)
# Out:
#                      Features       VIF
# 0          number of bedrooms  1.418402
# 1         number of bathrooms  2.491651
# 2                    lot area  1.980216
# 3            number of floors  1.939319
# 4          waterfront present  1.017609
# 5      condition of the house  1.121816
# 6          grade of the house  2.440119
# 7        Area of the basement  1.553871
# 8                   Lattitude  1.065200
# 9                   Longitude  1.345292
# 10          living_area_renov  2.223780
# 11             lot_area_renov  2.033372
# 12   Number of schools nearby  1.001468
# 13  Distance from the airport  1.001085
# 14      Year since renovation  1.012873

# %%
X_normalized.to_csv("C
