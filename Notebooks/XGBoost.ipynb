# %%
import numpy as np
import pandas as pd
X = pd.read_csv("../Datasets/HousePriceIndia/Cleaned-House-Prices.csv")
Y =pd.read_csv("../Datasets/HousePriceIndia/ProcessedPrice.csv")
Y = Y["Price"]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13859 entries, 0 to 13858
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 13859 non-null  int64
#  1   number of bedrooms         13859 non-null  float64
#  2   number of bathrooms        13859 non-null  float64
#  3   lot area                   13859 non-null  float64
#  4   number of floors           13859 non-null  float64
#  5   waterfront present         13859 non-null  float64
#  6   condition of the house     13859 non-null  float64
#  7   grade of the house         13859 non-null  float64
#  8   Area of the basement       13859 non-null  float64
#  9   Lattitude                  13859 non-null  float64
#  10  Longitude                  13859 non-null  float64
#  11  living_area_renov          13859 non-null  float64
#  12  lot_area_renov             13859 non-null  float64
#  13  Number of schools nearby   13859 non-null  float64
#  14  Distance from the airport  13859 non-null  float64
#  15  Year since renovation      13859 non-null  float64
# dtypes: float64(15), int64(1)
# memory usage: 1.7 MB

# %%
X = X.drop(columns=["Unnamed: 0"])

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13859 entries, 0 to 13858
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   number of bedrooms         13859 non-null  float64
#  1   number of bathrooms        13859 non-null  float64
#  2   lot area                   13859 non-null  float64
#  3   number of floors           13859 non-null  float64
#  4   waterfront present         13859 non-null  float64
#  5   condition of the house     13859 non-null  float64
#  6   grade of the house         13859 non-null  float64
#  7   Area of the basement       13859 non-null  float64
#  8   Lattitude                  13859 non-null  float64
#  9   Longitude                  13859 non-null  float64
#  10  living_area_renov          13859 non-null  float64
#  11  lot_area_renov             13859 non-null  float64
#  12  Number of schools nearby   13859 non-null  float64
#  13  Distance from the airport  13859 non-null  float64
#  14  Year since renovation      13859 non-null  float64
# dtypes: float64(15)
# memory usage: 1.6 MB

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X ,Y,test_size=0.2, random_state=42)

# %%
from xgboost import XGBRegressor

# %%
xgb = XGBRegressor(max_depth=10,
    n_estimators=100,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42)
xgb.fit(X_train, Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
y_pred = xgb.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
mse = mean_squared_error(Y_test, y_pred)
print("Mean Squared Error:", mse)

# R² Score
r2 = r2_score(Y_test, y_pred)
print("R² Score:", r2)
# Out:
# Mean Squared Error: 6204785972.898936
# R² Score: 0.8586362600326538

# %%
import joblib

# %%
joblib.dump(xgb, 'xgb_model.joblib')
# Out:
# ['xgb_model.joblib']
